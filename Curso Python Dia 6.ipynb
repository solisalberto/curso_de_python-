# %% [markdown]
# # Dia 6
# ## Programación orientada a objetos
#
# ## temario
#   1.- Que es poo
#   2.- Entidades, clases y objetos
#   3.- Self, __init__ y el ciclo de vida de un objeto
#   4.- Atributos: De instancia vs de clase
#   5.- Metodo: instancia, clase
#   6.- Encapusalamiento y propiedades
#   7.- Herencia y Abstracción
#   8.- Polimorfismo
#   9.- Composicion vs herencia

# %% [markdown]
# ## 1.- Que es POO y por que usarla?
# 1.- Clases (Los Molde)
#
# Una clase es como el molde o plano para crear algo
#
# 2.- Objetos (Las creaciones)
#
# Un objeto es una instancia real tangible de una clase.

# %% [markdown]
# ## 2.- Entidades: Clases y Objetos

# %%
class Perro: #Se crea una clase
  def ladrar(self): #Metodo
    print("Woaf")

mi_perro = Perro() #Crea el objeto
mi_perro.ladrar() #Ejecuta el metodo
# Out:
# Woaf

# %% [markdown]
# ## 3.- Self, __init__ y el ciclo de vida de un objeto

# %%
class Perro:
# self es la referencia a la instancia actual
  def __init__(self, nombre, edad): #Constructor
    self.nombre = nombre
    self.edad = edad
  def presentarse(self):
    print(f"Soy {self.nombre} y tengo {self.edad} años")
naylah = Perro("Naylah", 5)
naylah.presentarse()
# 1.- __init__ no retorna la instancia; Python lo llama al crear el objeto
# 2.- Evita usar valores mutables como parametro por defecto
# Out:
# Soy Naylah y tengo 5 años

# %% [markdown]
# # 4.- Atributos: de instancia vs de clase

# %%
class Perro:
  patas = 4
  especie = "Caninis Familiaris" #Atributos de clase
  def __init__(self, nombre):
    self.nombre = nombre #Atributos de instancia

p1 = Perro("Firulais")
p2 = Perro("Bobby")

print(p1.especie)
print(p2.especie)
print("------------")
p2.especie = "Gato"
print(p1.especie) #Cambio el atributo de la clase para una de los objetos
print(p2.especie)
# Out:
# Caninis Familiaris
# Caninis Familiaris
# ------------
# Caninis Familiaris
# Gato

# %%
print(p1.especie)
print(p2.especie)
# Out:
# Caninis Familiaris
# Gato

# %% [markdown]
# # Metodos: De instancia, clase
# Un metodo de instancia es una funcion dentro de una clase que:
# - Opera sobre un objeto concreto (una instancia)
# - Puede acceder y modificar los atributos de ese objeto
# -Recibe como primer parametro a self

# %%
# (ya lo hemos usado)
class tuClase:
    def metodo(self):
        pass
#metodo -> método de instancia
#self -> referencia al objeto que llama al método

# %%
# Calculadora:
class Calculadora:
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2
    def sumar(self):
      print(self.num1 + self.num2)
    def resta(self):
      print(self.num1 - self.num2)
    def multiplicacion(self):
      print(self.num1 * self.num2)
    def division(self):
      if self.num2 == 0:
        print("No se puede dividir por cero")
      else:
        print(self.num1 / self.num2)
Calculadora = Calculadora(10, 0)
Calculadora.division()
Calculadora.sumar()
Calculadora.multiplicacion()
# Out:
# No se puede dividir por cero
# 10
# 0

# %% [markdown]
# ###EJERCICIOS, CREAR UNA CLASE ANIMAL, donde tenga una instancia (constructor) de por lo menos 3 variables con un metodo y crea 4 objetos

# %%
class Animal: #1.- Clase
  def __init__(self, nombre, especie, patas, comida_favorita, sonido): #2.- Instancia
    self.nombre = nombre #3.- Variables
    self.especie = especie
    self.patas = patas
    self.comida_favorita = comida_favorita
    self.sonido = sonido

  def hacer_sonido(self): #4.- Metodo
    print(self.sonido)

gato = Animal("Rayitas", "Gato", 4, "Carne de Res", "miau") #4 Objetos
perro = Animal("Mechas", "Perro", 4, "Pollito Asado", "woof")
pajaro = Animal("Paco", "Perico", 2, "Semillas", "pipipi")
vaca = Animal("Manchas", "Vaca", 4, "Pasto", "muuu")

vaca.hacer_sonido()
gato.nombre = "Juan"
print(gato.nombre)
# Out:
# muuu
# Juan

# %% [markdown]
# ## 6.- Encapsulamientos y propiedades

# %%
class Cuenta:
  def __init__(self,saldo):
    self.__saldo = saldo #Privada
#Sirve para proteger los datos internos de un objeto y controlar como se leen o modifiquen
cuenta = Cuenta(1000)
cuenta.Cuenta = 2000 # si puedes editarlo pero no lo puedes imprimir
#print(cuenta._saldo) #Eror: no se puede acceder directamente

# %%
# Getters y setters
class Cuenta:
  def __init__(self,saldo):
    self.__saldo = saldo

  @property
  def saldo(self): #Getter
    #Permite ller el valor de _saldo usando c.saldo
    return self.__saldo

  @saldo.setter
  def saldo(self, valor):
    # se ejecuta cuando hacemos c.saldo = valor
    self.__saldo = valor
c = Cuenta(300)
print(c.saldo)
c.saldo = 4000
print(c.saldo)
# Out:
# 300
# 4000

# %% [markdown]
# # 7.- Herencia y abstracción

# %%
# herencia
class Vehiculo: #Claser base (Padre)
  def __init__(self,marca,modelo):
    self.marca = marca
    self.modelo = modelo
  def descripcion(self):
    return f"{self.marca}: {self.modelo}"
  def mover(self):
    return "El vehiculo se esta moviendo"

#-----------------------------------------------------------
class Coche(Vehiculo): #subclase 1 (Clase hija)
  def mover(self):
    return "El coche se esta moviendo"
#-----------------------------------------------------------
class Moto(Vehiculo):
  def mover(self):
    return "La moto avanza sobre dos ruedas"

coche2 = Vehiculo("BYD", "Dolphin")
coche = Coche("Toyota", "Corolla")
moto = Moto("Yamaha", "R6")
print(coche2.mover())
print(coche2.mover())
print(coche.mover())
#aun que no volvimos a declarar el metodo dentro de descripcion, podemos seguir usandolo ya que lo heredo del padreprint(coche.mover())print(moto.descripcion())print(moto.mover())
# Out:
# El vehiculo se esta moviendo
# El vehiculo se esta moviendo
# El coche se esta moviendo

# %%
class Persona:
  def __init__(self,nombre,edad):
    self.nombre = nombre
    self.edad = edad
  def presentarse(self):
    print(f"Hola, soy {self.nombre} y tengo {self.edad} años")

class Estudiante(Persona):
  def __init__(self,nombre,edad,carrera):
      super().__init__(nombre,edad)
      self.carrera = carrera
  def presentarse(self):
      super().presentarse()
      print(f"Estudio la carrera de {self.carrera}")
# Reutiliza el constructor de la clase padre lo cual evita duplicar el código
# Ejucuta el comportamiento base y luego lo extiende
est = Estudiante("Ana", 21, "Programación")
est.presentarse()
# Out:
# Hola, soy Ana y tengo 21 años
# Estudio la carrera de Programación

# %%
#Abstraccion
class Animal:
  def hablar(self)
    raise NotImplementedError
class Gato(Animal)
  def hablar(self):
    print("Miau")

# %% [markdown]
# ## Polimorfismo
# (Justo ya lo implementamos)
# El polimorfismo signifa que diferentes objetos pueden responder al mismo mensaje (metodo) de forma distanta, siempre y cuando compras una interfaz comun

# %% [markdown]
# ## Composicion HAS-A
# Por que se llama composicion?
# Porque estas componiendo (armando) un objeto grande usando otros objetos
# Es un principio de POO donde una clase no hereda otra sino que contiene un objeto de esa clase

# %%
class Banco:
  def __init__(self,dinero):
    self.dinero = dinero
  def var_total(self):
    print(f"Total en la cuenta:  ${self.dinero}")
class Persona:
  def __init__(self,cuenta: Banco): #Indica que este parametro debería ser una instancia de la clase banco
    self.cuenta = cuenta #Persona tiene un baco, no hereda de el

# %% [markdown]
# ## 9.- Composicion Vs Herencia
# Esto se va a responder con pura teoría:
# No significa que alguna se mejor que otra simplemente que a aveces una te puede convenir más que otra:
#
# Herencia: un gato ES un animal pero "no sifinica que un gato tiene un animal"
# Composición: Una persona TIENE una cuenta (no "Una persona es un banco")
